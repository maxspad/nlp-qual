# %%
# Basics
import pandas as pd
import numpy as np
import sys 
from pprint import pprint
import pickle

# Skspacy
sys.path.append('../')
from skspacy import SpacyDocFeats, SpacyTokenFilter, SpacyTransformer

# Pipeline / transformation / models
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.svm import LinearSVC, LinearSVR
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Model Selection / Grid Search
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_validate
import sklearn.metrics as met
from sklearn.metrics import get_scorer_names

# Plotting
import matplotlib.pyplot as plt 
from matplotlib.cm import get_cmap
import wordcloud

# MLFlow tracking
import mlflow

# %% [markdown]
# ## Load Data

# %%
path = '../masterDbforNLPAnalysis.xlsx'
df = pd.read_excel(path)
df = df.iloc[:, 1:].set_index('rawCommentId')

# %%
df.shape
# Out:
# (2500, 12)

# %%
df['Q2'].value_counts(normalize=True)
# Out:
# 0    0.8064
# 1    0.1936
# Name: Q2, dtype: float64

# %% [markdown]
# ## Build Pipeline

# %%
mdl = LinearSVC(max_iter=5000) # default is 1000
pipe = Pipeline((
    ('ct', ColumnTransformer((
        ('bowpipe', Pipeline((
            ('tokfilt', SpacyTokenFilter()),
            ('vec', CountVectorizer()),
        )), [0]),
        ('docfeatspipe', Pipeline((
            ('docfeats', SpacyDocFeats(vectors=False)),
            ('scaler', MinMaxScaler())
        )), [0])
    ))),
    ('mdl', mdl)
))

# %%
pipe
# Out:
# Pipeline(steps=(('ct',
#                  ColumnTransformer(transformers=(('bowpipe',
#                                                   Pipeline(steps=(('tokfilt',
#                                                                    SpacyTokenFilter()),
#                                                                   ('vec',
#                                                                    CountVectorizer()))),
#                                                   [0]),
#                                                  ('docfeatspipe',
#                                                   Pipeline(steps=(('docfeats',
#                                                                    SpacyDocFeats(vectors=False)),
#                                                                   ('scaler',
#                                                                    MinMaxScaler()))),
#                                                   [0])))),
#                 ('mdl', LinearSVC(max_iter=5000))))

# %% [markdown]
# ## Set up Train/Test Sets
# We will use Q2 as predicted variable to start for simplicity's sake

# %%
TEXT_VAR = 'feedback'
TARGET_VAR = 'Q2'
X = df[TEXT_VAR].values.copy()[:, None].astype('str')
spacytf = SpacyTransformer(procs=1, prog=True)
X = spacytf.fit_transform(X)
y = df[TARGET_VAR].values.copy()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2500/2500 [00:07<00:00, 319.92it/s]

# %% [markdown]
# Hold aside a protected final validation set

# %%
RANDOM_SEED = 43
VAL_SET_SIZE = 0.15
Xtr, Xval, ytr, yval = train_test_split(X, y, test_size=VAL_SET_SIZE, random_state=RANDOM_SEED)

# %%
print(Xtr.shape, Xval.shape, ytr.shape, yval.shape)
# Out:
# (2125, 1) (375, 1) (2125,) (375,)

# %% [markdown]
# ## Run Hyperparameter Search

# %%
param_grid = {
    'ct__bowpipe__tokfilt__punct': [True, False],
    'ct__bowpipe__tokfilt__pron': [True, False],
    'ct__bowpipe__tokfilt__stop': [True, False],
    'ct__bowpipe__tokfilt__lemma': [True, False],
    'ct__bowpipe__vec__ngram_range': [(1,1), (1,2), (1,3)],
    'ct__bowpipe__vec__max_df': [0.90, 0.95, 1.0],
    'ct__bowpipe__vec__min_df': [1, 5, 10, 20],
    'ct__docfeatspipe__docfeats__token_count': [True, False],
    'ct__docfeatspipe__docfeats__pos_counts': [True, False],
    'ct__docfeatspipe__docfeats__ent_counts': [True, False],
    'mdl__C': [1, 0.1, 0.001, 0.0001],
    'mdl__class_weight': ['balanced', None]
}

# %%
metrics = ['accuracy', 'balanced_accuracy', 'roc_auc', 'f1', 'precision', 'recall']

# %% [markdown]
# ### 🚀 Run Search
# Run 10 searches of 100 fits, then one search of 1000 fits, keeping the top 25 for analysis later

# %%
NUM_ITERS = 100
searcher = RandomizedSearchCV(pipe, param_grid, n_iter=NUM_ITERS, scoring=metrics, 
                              cv=5, random_state=RANDOM_SEED, error_score=np.nan,
                              refit='balanced_accuracy', verbose=0, n_jobs=8)

# %%
SAVE_TOP_K_RUNS = 25
mlflow.sklearn.autolog(max_tuning_runs=SAVE_TOP_K_RUNS)

# %%
for i in range(10):
    searcher.fit(Xtr, ytr)
# Out:
# 2022/06/15 16:20:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '80174e6fab304bf79644e95ef2c49017', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2022/06/15 16:20:22 WARNING mlflow.utils: Truncated the value of the key `estimator`. Truncated value: `Pipeline(steps=(('ct',
#                  ColumnTransformer(transformers=(('bowpipe',
#                                                   Pipeline(steps=(('tokfilt',
#                                                                    SpacyTokenFilter()...`
# 2022/06/15 16:20:22 WARNING mlflow.utils: Truncated the value of the key `param_distributions`. Truncated value: `{'ct__bowpipe__tokfilt__punct': [True, False], 'ct__bowpipe__tokfilt__pron': [True, False], 'ct__bowpipe__tokfilt__stop': [True, False], 'ct__bowpipe__tokfilt__lemma': [True, False], 'ct__bowpipe__vec__ngram_range': [(1, 1), (1, 2), (1, 3)], 'ct__...`
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 60 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 673, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 604, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 1046, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 414, in fit_transform
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/home/maxspad/proj/nlp-qual/MaxClassification/../skspacy/skspacy.py", line 157, in transform
#     feats = np.hstack(feats)
#   File "<__array_function__ internals>", line 180, in hstack
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/numpy/core/shape_base.py", line 345, in hstack
#     return _nx.concatenate(arrs, 1)
#   File "<__array_function__ internals>", line 180, in concatenate
# ValueError: need at least one array to concatenate
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.83670588 0.80376471 0.856      0.81882353        nan 0.86682353
#  0.83058824 0.86164706        nan 0.84941176 0.86258824 0.83011765
#  0.832      0.84611765 0.82352941 0.82447059 0.84282353 0.82682353
#  0.85552941        nan 0.84235294 0.82870588 0.84705882 0.82070588
#         nan 0.82870588 0.81364706        nan 0.82870588 0.79435294
#  0.83905882 0.85270588 0.81458824 0.816      0.84564706 0.83623529
#  0.85552941 0.82682353 0.85552941 0.67011765 0.86305882 0.86870588
#  0.85364706 0.67388235 0.83858824 0.69364706        nan 0.83247059
#  0.82447059 0.69364706 0.85176471        nan 0.82682353 0.85129412
#  0.82729412        nan 0.82682353 0.83905882        nan 0.85505882
#  0.83058824 0.82917647 0.82305882 0.85176471 0.61364706 0.82588235
#  0.67576471        nan 0.84611765 0.82588235 0.83011765 0.83529412
#  0.86070588 0.58023529 0.82917647 0.79388235 0.83623529 0.79952941
#  0.83858824 0.82776471 0.84564706 0.848      0.82823529 0.696
#  0.84141176 0.83529412 0.82682353 0.84941176        nan 0.81364706
#  0.70352941 0.85364706 0.82023529 0.82729412 0.85694118 0.86447059
#  0.82823529 0.67858824        nan 0.82258824]
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0
08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 16:25:08 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 16:25:09 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9ff3059f3a7447aca5b5789ed181348e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2022/06/15 16:25:09 WARNING mlflow.utils: Truncated the value of the key `estimator`. Truncated value: `Pipeline(steps=(('ct',
#                  ColumnTransformer(transformers=(('bowpipe',
#                                                   Pipeline(steps=(('tokfilt',
#                                                                    SpacyTokenFilter()...`
# 2022/06/15 16:25:09 WARNING mlflow.utils: Truncated the value of the key `param_distributions`. Truncated value: `{'ct__bowpipe__tokfilt__punct': [True, False], 'ct__bowpipe__tokfilt__pron': [True, False], 'ct__bowpipe__tokfilt__stop': [True, False], 'ct__bowpipe__tokfilt__lemma': [True, False], 'ct__bowpipe__vec__ngram_range': [(1, 1), (1, 2), (1, 3)], 'ct__...`
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 60 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 673, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py", line 604, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 1046, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 414, in fit_transform
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/home/maxspad/proj/nlp-qual/MaxClassification/../skspacy/skspacy.py", line 157, in transform
#     feats = np.hstack(feats)
#   File "<__array_function__ internals>", line 180, in hstack
#   File "/home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/numpy/core/shape_base.py", line 345, in hstack
#     return _nx.concatenate(arrs, 1)
#   File "<__array_function__ internals>", line 180, in concatenate
# ValueError: need at least one array to concatenate
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.83670588 0.80376471 0.856      0.81882353        nan 0.86682353
#  0.83058824 0.86164706        nan 0.84941176 0.86258824 0.83011765
#  0.832      0.84611765 0.82352941 0.82447059 0.84282353 0.82682353
#  0.85552941        nan 0.84235294 0.82870588 0.84705882 0.82070588
#         nan 0.82870588 0.81364706        nan 0.82870588 0.79435294
#  0.83905882 0.85270588 0.81458824 0.816      0.84564706 0.83623529
#  0.85552941 0.82682353 0.85552941 0.67011765 0.86305882 0.86870588
#  0.85364706 0.67388235 0.83858824 0.69364706        nan 0.83247059
#  0.82447059 0.69364706 0.85176471        nan 0.82682353 0.85129412
#  0.82729412        nan 0.82682353 0.83905882        nan 0.85505882
#  0.83058824 0.82917647 0.82305882 0.85176471 0.61364706 0.82588235
#  0.67576471        nan 0.84611765 0.82588235 0.83011765 0.83529412
#  0.86070588 0.58023529 0.82917647 0.79388235 0.83623529 0.79952941
#  0.83858824 0.82776471 0.84564706 0.848      0.82823529 0.696
#  0.84141176 0.83529412 0.82682353 0.84941176        nan 0.81364706
#  0.70352941 0.85364706 0.82023529 0.82729412 0.85694118 0.86447059
#  0.82823529 0.67858824        nan 0.82258824]
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.77316996 0.72657328 0.72848745 0.69788884        nan 0.70401371
#  0.7129021  0.7145406         nan 0.69720644 0.67806416 0.73003233
#  0.77416281 0.78383099 0.70563726 0.53777356 0.77887745 0.55577688
#  0.72624482        nan 0.71809984 0.70298056 0.73379086 0.75360603
#         nan 0.6835178  0.5               nan 0.55400085 0.70718012
#  0.68900018 0.67887571 0.67681001 0.6913032  0.62000427 0.72029168
#  0.70783295 0.55480091 0.68828018 0.74860035 0.70657889 0.709077
#  0.70470577 0.74604596 0.70122888 0.7562403         nan 0.77346255
#  0.53972718 0.75526349 0.69967831        nan 0.54506366 0.72562724
#  0.68554114        nan 0.55576105 0.77849975        nan 0.71524677
#  0.56000847 0.55528166 0.69858637 0.68896007 0.70608214 0.75385732
#  0.74622607        nan 0.7127283  0.54349216 0.70388094 0.77716944
#  0.7197884  0.67485447 0.56113002 0.7068911  0.71535106 0.71622433
#  0.69541886 0.56024715 0.62000427 0.73534654 0.55372682 0.75671025
#  0.72048135 0.77716944 0.68622977 0.72447034        nan 0.5
#  0.75840495 0.73298566 0.75133762 0.55898132 0.71355154 0.70551402
#  0.5586142  0.75185492        nan 0.70400415]
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.86020049 0.74687355 0.79978698 0.73368977        nan 0.8685548
#  0.76720588 0.82171249        nan 0.79412463 0.86025093 0.77633255
#  0.8580289  0.86617786 0.73546569 0.82148975 0.86453572 0.64129102
#  0.80180735        nan 0.76549232 0.73288464 0.85119879 0.8482801
# ...
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:15 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:15 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:15 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:15 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:08:16 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`

# %%
searcher.set_params(n_iter=1000)
searcher.fit(Xtr, ytr)
# Out:
# 2022/06/15 17:08:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bd8ff874cb9e45a681107029052d0b38', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2022/06/15 17:08:17 WARNING mlflow.utils: Truncated the value of the key `estimator`. Truncated value: `Pipeline(steps=(('ct',
#                  ColumnTransformer(transformers=(('bowpipe',
#                                                   Pipeline(steps=(('tokfilt',
#                                                                    SpacyTokenFilter()...`
# 2022/06/15 17:08:17 WARNING mlflow.utils: Truncated the value of the key `param_distributions`. Truncated value: `{'ct__bowpipe__tokfilt__punct': [True, False], 'ct__bowpipe__tokfilt__pron': [True, False], 'ct__bowpipe__tokfilt__stop': [True, False], 'ct__bowpipe__tokfilt__lemma': [True, False], 'ct__bowpipe__vec__ngram_range': [(1, 1), (1, 2), (1, 3)], 'ct__...`
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxspad/anaconda3/envs/nlp-qual/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `(('ct', ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountV...`
# 2022/06/15 17:55:28 WARNING mlflow.utils: Truncated the value of the key `ct`. Truncated value: `ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter()),
#                                                  ('vec', CountVectorize...`
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=(('ct',
#                                               ColumnTransformer(transformers=(('bowpipe',
#                                                                                Pipeline(steps=(('tokfilt',
#                                                                                                 SpacyTokenFilter()),
#                                                                                                ('vec',
#                                                                                                 CountVectorizer()))),
#                                                                                [0]),
#                                                                               ('docfeatspipe',
#                                                                                Pipeline(steps=(('docfeats',
#                                                                                                 SpacyDocFeats(vectors=False)),
#                                                                                                ('scaler',
#                                                                                                 MinMaxScaler()))),
#                                                                                [0])))),
#                                              ('mdl',
#                                               LinearSVC(max_iter=5000)))),
#                    n_iter=1000, n_jobs=8,
#                    param...
#                                         'ct__docfeatspipe__docfeats__ent_counts': [True,
#                                                                                    False],
#                                         'ct__docfeatspipe__docfeats__pos_counts': [True,
#                                                                                    False],
#                                         'ct__docfeatspipe__docfeats__token_count': [True,
#                                                                                     False],
#                                         'mdl__C': [1, 0.1, 0.001, 0.0001],
#                                         'mdl__class_weight': ['balanced',
#                                                               None]},
#                    random_state=43, refit='balanced_accuracy',
#                    scoring=['accuracy', 'balanced_accuracy', 'roc_auc', 'f1',
#                             'precision', 'recall'])

# %% [markdown]
# ## Evaluate Models and Hyperparams
# ### Load Best Model from Hyperparam Search

# %%
TARGET_METRIC = 'metrics.best_cv_score'
runs = mlflow.search_runs()
runs = runs.dropna(subset=TARGET_METRIC).sort_values(TARGET_METRIC, ascending=False)
top_run = runs.iloc[0,:]
top_run_id = top_run['run_id']
top_run_model_path = f'mlruns/0/{top_run_id}/artifacts/best_estimator/model.pkl'
with open(top_run_model_path, 'rb') as f:
    mdl = pickle.load(f)
# logged_model = f'runs:/{top_run_id}/best_estimator'
# loaded_model = mlflow.pyfunc.load_model(logged_model)

print(f'Best model is {top_run_id}')
print(f'Best model score ({TARGET_METRIC}) is {top_run[TARGET_METRIC]}')
# Out:
# Best model is ed07d512ea354bb1942f53417ad988c0
# Best model score (metrics.best_cv_score) is 0.7838309855645089

# %% [markdown]
# ### Evaluate Model on Validation Set

# %%
yval_pred = mdl.predict(Xval)

# %%
import sklearn.metrics as mets

# %%
def get_metrics(y, p):
    return {
        'balanced_accuracy': mets.balanced_accuracy_score(y, p),
        'accuracy': mets.accuracy_score(y, p),
        'roc_auc': mets.roc_auc_score(y, p),
        'f1': mets.f1_score(y, p),
        'precision': mets.precision_score(y, p),
        'recall': mets.recall_score(y, p),
        'confusion': mets.confusion_matrix(y, p),
        'clfrep': mets.classification_report(y, p)
    }

# %%
pprint(mdl.get_params())
# Out:
# {'ct': ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter(punct=False)),
#                                                  ('vec',
#                                                   CountVectorizer(max_df=0.9,
#                                                                   min_df=5,
#                                                                   ngram_range=(1,
#                                                                                2))))),
#                                  [0]),
#                                 ('docfeatspipe',
#                                  Pipeline(steps=(('docfeats',
#                                                   SpacyDocFeats(ent_counts=False,
#                                                                 vectors=False)),
#                                                  ('scaler', MinMaxScaler()))),
#                                  [0]))),
#  'ct__bowpipe': Pipeline(steps=(('tokfilt', SpacyTokenFilter(punct=False)),
#                 ('vec',
#                  CountVectorizer(max_df=0.9, min_df=5, ngram_range=(1, 2))))),
#  'ct__bowpipe__memory': None,
#  'ct__bowpipe__steps': (('tokfilt', SpacyTokenFilter(punct=False)),
#                         ('vec',
#                          CountVectorizer(max_df=0.9, min_df=5, ngram_range=(1, 2)))),
#  'ct__bowpipe__tokfilt': SpacyTokenFilter(punct=False),
#  'ct__bowpipe__tokfilt__lemma': False,
#  'ct__bowpipe__tokfilt__mrms': True,
#  'ct__bowpipe__tokfilt__pron': True,
#  'ct__bowpipe__tokfilt__punct': False,
#  'ct__bowpipe__tokfilt__stop': True,
#  'ct__bowpipe__tokfilt__token_sep': ' ',
#  'ct__bowpipe__vec': CountVectorizer(max_df=0.9, min_df=5, ngram_range=(1, 2)),
#  'ct__bowpipe__vec__analyzer': 'word',
#  'ct__bowpipe__vec__binary': False,
#  'ct__bowpipe__vec__decode_error': 'strict',
#  'ct__bowpipe__vec__dtype': <class 'numpy.int64'>,
#  'ct__bowpipe__vec__encoding': 'utf-8',
#  'ct__bowpipe__vec__input': 'content',
#  'ct__bowpipe__vec__lowercase': True,
#  'ct__bowpipe__vec__max_df': 0.9,
#  'ct__bowpipe__vec__max_features': None,
#  'ct__bowpipe__vec__min_df': 5,
#  'ct__bowpipe__vec__ngram_range': (1, 2),
#  'ct__bowpipe__vec__preprocessor': None,
#  'ct__bowpipe__vec__stop_words': None,
#  'ct__bowpipe__vec__strip_accents': None,
#  'ct__bowpipe__vec__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'ct__bowpipe__vec__tokenizer': None,
#  'ct__bowpipe__vec__vocabulary': None,
#  'ct__bowpipe__verbose': False,
#  'ct__docfeatspipe': Pipeline(steps=(('docfeats', SpacyDocFeats(ent_counts=False, vectors=False)),
#                 ('scaler', MinMaxScaler()))),
#  'ct__docfeatspipe__docfeats': SpacyDocFeats(ent_counts=False, vectors=False),
#  'ct__docfeatspipe__docfeats__ent_counts': False,
#  'ct__docfeatspipe__docfeats__pos_counts': True,
#  'ct__docfeatspipe__docfeats__token_count': True,
#  'ct__docfeatspipe__docfeats__vectors': False,
#  'ct__docfeatspipe__memory': None,
#  'ct__docfeatspipe__scaler': MinMaxScaler(),
#  'ct__docfeatspipe__scaler__clip': False,
#  'ct__docfeatspipe__scaler__copy': True,
#  'ct__docfeatspipe__scaler__feature_range': (0, 1),
#  'ct__docfeatspipe__steps': (('docfeats',
#                               SpacyDocFeats(ent_counts=False, vectors=False)),
#                              ('scaler', MinMaxScaler())),
#  'ct__docfeatspipe__verbose': False,
#  'ct__n_jobs': None,
#  'ct__remainder': 'drop',
#  'ct__sparse_threshold': 0.3,
#  'ct__transformer_weights': None,
#  'ct__transformers': (('bowpipe',
#                        Pipeline(steps=(('tokfilt', SpacyTokenFilter(punct=False)),
#                 ('vec',
#                  CountVectorizer(max_df=0.9, min_df=5, ngram_range=(1, 2))))),
#                        [0]),
#                       ('docfeatspipe',
#                        Pipeline(steps=(('docfeats', SpacyDocFeats(ent_counts=False, vectors=False)),
#                 ('scaler', MinMaxScaler()))),
#                        [0])),
#  'ct__verbose': False,
#  'ct__verbose_feature_names_out': True,
#  'mdl': LinearSVC(C=0.001, class_weight='balanced', max_iter=5000),
#  'mdl__C': 0.001,
#  'mdl__class_weight': 'balanced',
#  'mdl__dual': True,
#  'mdl__fit_intercept': True,
#  'mdl__intercept_scaling': 1,
#  'mdl__loss': 'squared_hinge',
#  'mdl__max_iter': 5000,
#  'mdl__multi_class': 'ovr',
#  'mdl__penalty': 'l2',
#  'mdl__random_state': None,
#  'mdl__tol': 0.0001,
#  'mdl__verbose': 0,
#  'memory': None,
#  'steps': [('ct',
#             ColumnTransformer(transformers=(('bowpipe',
#                                  Pipeline(steps=(('tokfilt',
#                                                   SpacyTokenFilter(punct=False)),
#                                                  ('vec',
#                                                   CountVectorizer(max_df=0.9,
#                                                                   min_df=5,
#                                                                   ngram_range=(1,
#                                                                                2))))),
#                                  [0]),
#                                 ('docfeatspipe',
#                                  Pipeline(steps=(('docfeats',
#                                                   SpacyDocFeats(ent_counts=False,
#                                                                 vectors=False)),
#                                                  ('scaler', MinMaxScaler()))),
#                                  [0])))),
#            ('mdl', LinearSVC(C=0.001, class_weight='balanced', max_iter=5000))],
#  'verbose': False}

# %%
pprint(get_metrics(yval, yval_pred))
# Out:
# {'accuracy': 0.8373333333333334,
#  'balanced_accuracy': 0.7794781438074121,
#  'clfrep': '              precision    recall  f1-score   support\n'
#            '\n'
#            '           0       0.90      0.89      0.89       287\n'
#            '           1       0.65      0.67      0.66        88\n'
#            '\n'
#            '    accuracy                           0.84       375\n'
#            '   macro avg       0.77      0.78      0.78       375\n'
#            'weighted avg       0.84      0.84      0.84       375\n',
#  'confusion': array([[255,  32],
#        [ 29,  59]]),
#  'f1': 0.6592178770949721,
#  'precision': 0.6483516483516484,
#  'recall': 0.6704545454545454,
#  'roc_auc': 0.7794781438074121}

# %%
print(get_metrics(yval, yval_pred)['confusion'])
# Out:
# [[255  32]
#  [ 29  59]]

# %%
# ppv = tp / (tp + fp)
ppv = 255 / (255 + 29)
print(ppv)
# Out:
# 0.897887323943662

# %%
def get_feat_weights_df(mdl):
    coefs = mdl[-1].coef_.copy().flatten()
    feats = mdl[:-1].get_feature_names_out()
    return pd.DataFrame({
        'feature': [f.split('__')[1] for f in feats],
        'coef': coefs,
        'coef.abs': np.abs(coefs),
        'positive': [c >= 0 for c in coefs]
    })

feat_weights = get_feat_weights_df(mdl)
feat_weights = feat_weights.sort_values('coef')
feat_weights = feat_weights.set_index('feature')

# %%
feat_weights.head(20)[['coef','coef.abs']]
# Out:
#                    coef  coef.abs
# feature
# excellent     -0.115045  0.115045
# management    -0.071909  0.071909
# able to       -0.064640  0.064640
# able          -0.052878  0.052878
# assessment    -0.051671  0.051671
# nan           -0.048896  0.048896
# required      -0.041122  0.041122
# up            -0.039984  0.039984
# thorough      -0.038969  0.038969
# for the       -0.037899  0.037899
# patient       -0.037838  0.037838
# plans         -0.037601  0.037601
# presentation  -0.035755  0.035755
# resident      -0.034961  0.034961
# had           -0.034456  0.034456
# manage        -0.033248  0.033248
# was able      -0.032299  0.032299
# great         -0.032296  0.032296
# were          -0.031688  0.031688
# independently -0.031555  0.031555

# %%
feat_weights.tail(20)[['coef','coef.abs']]
# Out:
#                  coef  coef.abs
# feature
# is           0.042793  0.042793
# head         0.043512  0.043512
# remember to  0.044202  0.044202
# some         0.044687  0.044687
# prompting    0.047665  0.047665
# continue to  0.048585  0.048585
# can          0.048755  0.048755
# of           0.054926  0.054926
# in           0.055486  0.055486
# would        0.059211  0.059211
# continue     0.060871  0.060871
# we           0.061598  0.061598
# have         0.062862  0.062862
# history      0.063714  0.063714
# use          0.069313  0.069313
# remember     0.070844  0.070844
# you          0.088632  0.088632
# more         0.088820  0.088820
# discussed    0.117610  0.117610
# to           0.123214  0.123214

# %% [markdown]
# ### Wordcloud -  All Words
#
# Red = weighted toward Q2 = 0
#
# Green = weighted toward Q2 = 1

# %%
def color_func(word, *args, **kwargs):
    if not feat_weights.loc[word, 'positive']: return (186, 60, 60)
    else: return (60, 186, 72)

# %%
fw_for_wc = feat_weights[['coef.abs']].to_dict()['coef.abs']
wc = wordcloud.WordCloud(width=800, height=400, color_func=color_func)
wc = wc.fit_words(fw_for_wc)
plt.figure(figsize=(10,20))
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %% [markdown]
# ### Wordcloud -  Words Weighted toward Q2 = 1

# %%
fw_for_wc = feat_weights[feat_weights['coef'] >= 0][['coef.abs']].to_dict()['coef.abs']
wc = wordcloud.WordCloud(width=800, height=400, colormap=get_cmap('Greens'))
wc = wc.fit_words(fw_for_wc)
plt.figure(figsize=(10,20))
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %% [markdown]
# ### Wordcloud -  Words Weighted AGAINST Q2 = 1

# %%
fw_for_wc = feat_weights[feat_weights['coef'] < 0][['coef.abs']].to_dict()['coef.abs']
wc = wordcloud.WordCloud(width=800, height=400, colormap=get_cmap('Reds'))
wc = wc.fit_words(fw_for_wc)
plt.figure(figsize=(10,20))
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %% [markdown]
# ---

# %%
from sklearn.metrics import get_scorer_names
print(get_scorer_names())
# Out:
# ['accuracy', 'adjusted_mutual_info_score', 'adjusted_rand_score', 'average_precision', 'balanced_accuracy', 'completeness_score', 'explained_variance', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'fowlkes_mallows_score', 'homogeneity_score', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted', 'matthews_corrcoef', 'max_error', 'mutual_info_score', 'neg_brier_score', 'neg_log_loss', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_gamma_deviance', 'neg_mean_poisson_deviance', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_median_absolute_error', 'neg_root_mean_squared_error', 'normalized_mutual_info_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'r2', 'rand_score', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'roc_auc', 'roc_auc_ovo', 'roc_auc_ovo_weighted', 'roc_auc_ovr', 'roc_auc_ovr_weighted', 'top_k_accuracy', 'v_measure_score']
